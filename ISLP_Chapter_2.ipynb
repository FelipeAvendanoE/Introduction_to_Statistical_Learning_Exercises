# %%
pip install ISLP;

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ISLP
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import pandas as pd

# %% [markdown]
# # 8. College Data set

# %% [markdown]
# (a) Use the pd.read_csv() function to read the data into Python. Call
# the loaded data college. Make sure that you have the directory
# set to the correct location for the data.

# %%
# a) Read csv
College = pd.read_csv('/content/College.csv')

# %%
College.head()
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %% [markdown]
# (b) Look at the data used in the notebook by creating and running
# a new cell with just the code college in it. You should notice
# that the first column is just the name of each university in a
# column named something like Unnamed: 0. We don’t really want
# pandas to treat this as data. However, it may be handy to have
# these names for later.

# %%
# b) Change column into header
college = pd.read_csv('College.csv', index_col=0)
college.index.name = 'College'

# %%
college.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# College
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
# ...

# %% [markdown]
# (c) Use the describe() method of to produce a numerical summary
# of the variables in the data set.

# %%
# c)
college.describe(include = 'all').fillna('-')
# Out:
#        Private         Apps       Accept      Enroll  Top10perc  Top25perc  \
# count      777        777.0        777.0       777.0      777.0      777.0
# unique       2            -            -           -          -          -
# top        Yes            -            -           -          -          -
# freq       565            -            -           -          -          -
# mean         -  3001.638353  2018.804376  779.972973  27.558559  55.796654
# std          -  3870.201484  2451.113971   929.17619  17.640364  19.804778
# min          -         81.0         72.0        35.0        1.0        9.0
# 25%          -        776.0        604.0       242.0       15.0       41.0
# 50%          -       1558.0       1110.0       434.0       23.0       54.0
# 75%          -       3624.0       2424.0       902.0       35.0       69.0
# max          -      48094.0      26330.0      6392.0       96.0      100.0
#
# ...

# %%
college[['Top10perc', 'Apps', 'Enroll']]
# Out:
#                                 Top10perc   Apps  Enroll
# College
# Abilene Christian University           23   1660     721
# Adelphi University                     16   2186     512
# Adrian College                         22   1428     336
# Agnes Scott College                    60    417     137
# Alaska Pacific University              16    193      55
# ...                                   ...    ...     ...
# Worcester State College                 4   2197     543
# Xavier University                      24   1959     695
# Xavier University of Louisiana         34   2097     695
# Yale University                        95  10705    1317
# York College of Pennsylvania           28   2989     691
#
# [777 rows x 3 columns]

# %% [markdown]
# (d) Use the pd.plotting.scatter_matrix() function to produce a
# scatterplot matrix of the first columns [Top10perc, Apps, Enroll].

# %%
# d)

sns.pairplot(college[['Top10perc', 'Apps', 'Enroll']]);

# %% [markdown]
# (e) Use the boxplot() method of college to produce side-by-side
# boxplots of Outstate versus Private.

# %%
# e)

sns.boxplot(x = college['Private'], y = college['Outstate'], order = ['No', 'Yes']);

# %% [markdown]
# (f) Create a new qualitative variable, called Elite, by binning the
# Top10perc variable into two groups based on whether or not the
# proportion of students coming from the top 10% of their high
# school classes exceeds 50%.
#
# Use the value_counts() method of college['Elite'] to see how
# many elite universities there are. Finally, use the boxplot() method
# again to produce side-by-side boxplots of Outstate versus Elite.

# %%
# f)

college['Elite'] = pd.cut(college['Top10perc'], [0,50,100], labels=['No', 'Yes'])

# %%
college['Elite'].value_counts()
# Out:
# Elite
# No     699
# Yes     78
# Name: count, dtype: int64

# %%
sns.boxplot(x = college['Elite'], y = college['Outstate']);

# %% [markdown]
# (g) Use the plot.hist() method of college to produce some histograms with differing numbers of bins for a few of the quantitative variables. The command plt.subplots(2, 2) may be useful: it will divide the plot window into four regions so that four
# plots can be made simultaneously. By changing the arguments
# you can divide the screen up in other combinations.

# %%
# g)

Lista = ['Room.Board', 'Books', 'Personal', 'PhD']

fig, axes = plt.subplots(2,2, figsize=(10, 10))
axes = axes.flatten()
for i, j in enumerate(Lista):
  sns.histplot(college[j], ax = axes[i])

# %% [markdown]
# # 9. Auto Data set

# %% [markdown]
# In the first place we will perform an Exploratory Data Analysis and make sure we don't have any missing data.

# %%
Auto = pd.read_csv('/content/Auto.csv')

# %%
#We have 397 rows and 9 columns
Auto.shape
# Out:
# (397, 9)

# %%
#There are no missing values (NA), keep in mind this doesn't check for empty strings or faulty data.
Auto.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# year            0
# origin          0
# name            0
# dtype: int64

# %%
#Data looks fine at first glance
Auto.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0        130    3504          12.0    70
# 1  15.0          8         350.0        165    3693          11.5    70
# 2  18.0          8         318.0        150    3436          11.0    70
# 3  16.0          8         304.0        150    3433          12.0    70
# 4  17.0          8         302.0        140    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
# The horsepower column in an object, this requires further inspection.
Auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           397 non-null    float64
#  1   cylinders     397 non-null    int64
#  2   displacement  397 non-null    float64
#  3   horsepower    397 non-null    object
#  4   weight        397 non-null    int64
#  5   acceleration  397 non-null    float64
#  6   year          397 non-null    int64
#  7   origin        397 non-null    int64
#  8   name          397 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.0+ KB

# %%
# Horsepower has 94 unique values.
Auto.describe(include = 'all').fillna('-')
# Out:
#               mpg cylinders displacement  horsepower       weight  \
# count       397.0     397.0        397.0       392.0        397.0
# unique          -       5.0            -           -            -
# top             -       4.0            -           -            -
# freq            -     203.0            -           -            -
# mean    23.515869         -   193.532746  104.469388  2970.261965
# std      7.825804         -   104.379583    38.49116   847.904119
# min           9.0         -         68.0        46.0       1613.0
# 25%          17.5         -        104.0        75.0       2223.0
# 50%          23.0         -        146.0        93.5       2800.0
# 75%          29.0         -        262.0       126.0       3609.0
# max          46.6         -        455.0       230.0       5140.0
#
#        acceleration       year origin        name
# count         397.0      397.0  397.0         397
# unique            -          -    3.0         304
# ...

# %%
# We have missing values in the data ("?")
Auto['horsepower'].unique()
# Out:
# array(['130', '165', '150', '140', '198', '220', '215', '225', '190',
#        '170', '160', '95', '97', '85', '88', '46', '87', '90', '113',
#        '200', '210', '193', '?', '100', '105', '175', '153', '180', '110',
#        '72', '86', '70', '76', '65', '69', '60', '80', '54', '208', '155',
#        '112', '92', '145', '137', '158', '167', '94', '107', '230', '49',
#        '75', '91', '122', '67', '83', '78', '52', '61', '93', '148',
#        '129', '96', '71', '98', '115', '53', '81', '79', '120', '152',
#        '102', '108', '68', '58', '149', '89', '63', '48', '66', '139',
#        '103', '125', '133', '138', '135', '142', '77', '62', '132', '84',
#        '64', '74', '116', '82'], dtype=object)

# %%
# We turn horsepower into a numeric column and we count the rows that have a missing value.
Auto['horsepower'] = pd.to_numeric(Auto['horsepower'], errors = 'coerce')

Auto.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      5
# weight          0
# acceleration    0
# year            0
# origin          0
# name            0
# dtype: int64

# %%
#We drop the five rows with missing data.
Auto.dropna()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0       130.0    3504          12.0    70
# 1    15.0          8         350.0       165.0    3693          11.5    70
# 2    18.0          8         318.0       150.0    3436          11.0    70
# 3    16.0          8         304.0       150.0    3433          12.0    70
# 4    17.0          8         302.0       140.0    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 392  27.0          4         140.0        86.0    2790          15.6    82
# 393  44.0          4          97.0        52.0    2130          24.6    82
# 394  32.0          4         135.0        84.0    2295          11.6    82
# 395  28.0          4         120.0        79.0    2625          18.6    82
# 396  31.0          4         119.0        82.0    2720          19.4    82
#
#      origin                       name
# ...

# %%
# Origin represents the country of origin. We will turn it into a categorical variable.
# (1. American, 2. European, 3. Japanese)

Auto['origin'] = Auto['origin'].astype('category')

# %%
# Cylinders represents the number or cylinders (3 to 8). We will turn it into a categorical variable.

Auto['cylinders'] = Auto['cylinders'].astype('category')

# %% [markdown]
# (a) Which of the predictors are quantitative, and which are qualitative?

# %%
Auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           397 non-null    float64
#  1   cylinders     397 non-null    category
#  2   displacement  397 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        397 non-null    int64
#  5   acceleration  397 non-null    float64
#  6   year          397 non-null    int64
#  7   origin        397 non-null    category
#  8   name          397 non-null    object
# dtypes: category(2), float64(4), int64(2), object(1)
# memory usage: 22.9+ KB

# %% [markdown]
# # quantitative
#
# * mpg
# * displacement
# * horsepower
# * weight
# * acceleration
# * year
#
# # qualitative
#
# * origin
# * cylinders
# * name

# %% [markdown]
# (b) What is the range of each quantitative predictor? You can answer this using the min() and max() methods in numpy.

# %%
Auto.describe().loc[['min','max']]
# Out:
#       mpg  displacement  horsepower  weight  acceleration  year
# min   9.0          68.0        46.0  1613.0           8.0  70.0
# max  46.6         455.0       230.0  5140.0          24.8  82.0

# %% [markdown]
# (c) What is the mean and standard deviation of each quantitative
# predictor?

# %%
Auto.describe().loc[['mean','std']]
# Out:
#             mpg  displacement  horsepower       weight  acceleration  \
# mean  23.515869    193.532746  104.469388  2970.261965     15.555668
# std    7.825804    104.379583   38.491160   847.904119      2.749995
#
#            year
# mean  75.994962
# std    3.690005

# %% [markdown]
# (d) Now remove the 10th through 85th observations. What is the
# range, mean, and standard deviation of each predictor in the
# subset of the data that remains?

# %%
Auto2 = Auto.drop(range(10,86))

# %%
Auto2.describe().loc[['min','max','mean','std']]
# Out:
#             mpg  displacement  horsepower       weight  acceleration  \
# min   11.000000     68.000000   46.000000  1649.000000      8.500000
# max   46.600000    455.000000  230.000000  4997.000000     24.800000
# mean  24.444860    187.174455  101.003155  2933.183801     15.709034
# std    7.899928     99.864568   36.003208   809.638650      2.706441
#
#            year
# min   70.000000
# max   82.000000
# mean  77.143302
# std    3.128202

# %% [markdown]
# (e) Using the full data set, investigate the predictors graphically,
# using scatterplots or other tools of your choice. Create some plots
# highlighting the relationships among the predictors. Comment
# on your findings.

# %%
sns.pairplot(Auto, hue = 'origin');

# %%
sns.boxplot(x = Auto['origin'], y = Auto['mpg']);

# %%
sns.boxplot(x = Auto['cylinders'], y = Auto['mpg'], hue = Auto['origin']);

# %% [markdown]
# (f) Suppose that we wish to predict gas mileage (mpg) on the basis
# of the other variables. Do your plots suggest that any of the
# other variables might be useful in predicting mpg? Justify your
# answer.

# %% [markdown]
# * The country of Origin
#
# Cars made in the United States tend to consume more fuel than cars made in either Europe or Japan.
#
# * Horsepower
#
# The more powerful a car is the more fuel it will consume

# %% [markdown]
# # 10. Boston Data set

# %% [markdown]
# (a) To begin, load in the Boston data set, which is part of the ISLP
# library.

# %%
Boston = ISLP.load_data('Boston')

# %% [markdown]
# (b) How many rows are in this data set? How many columns? What
# do the rows and columns represent?

# %%
Boston.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  lstat    506 non-null    float64
#  12  medv     506 non-null    float64
# dtypes: float64(10), int64(3)
# memory usage: 51.5 KB

# %% [markdown]
# We have 506 rows and 13 columns. They represent housing values in suburbs of Boston.
#
#
#
#     crim: per capita crime rate by town.
#
#     zn: proportion of residential land zoned for lots over 25,000 sq.ft.
#
#     indus: proportion of non-retail business acres per town.
#
#     chas: Charles River dummy variable (= 1 if tract bounds river; 0 otherwise).
#
#     nox: nitrogen oxides concentration (parts per 10 million).
#
#     rm: average number of rooms per dwelling.
#
#     age: proportion of owner-occupied units built prior to 1940.
#
#     dis: weighted mean of distances to five Boston employment centres.
#
#     rad: index of accessibility to radial highways.
#
#     tax: full-value property-tax rate per $10,000.
#
#     ptratio: pupil-teacher ratio by town.
#
#     lstat: lower status of the population (percent).
#
#     medv: median value of owner-occupied homes in $1000s.

# %% [markdown]
# (c) Make some pairwise scatterplots of the predictors (columns) in
# this data set. Describe your findings.

# %%
sns.pairplot(data = Boston, vars = ['medv','crim', 'zn', 'indus', 'dis']);

# %% [markdown]
# (d) Are any of the predictors associated with per capita crime rate?
# If so, explain the relationship.

# %%
Boston.corr().round(2)
# Out:
#          crim    zn  indus  chas   nox    rm   age   dis   rad   tax  ptratio  \
# crim     1.00 -0.20   0.41 -0.06  0.42 -0.22  0.35 -0.38  0.63  0.58     0.29
# zn      -0.20  1.00  -0.53 -0.04 -0.52  0.31 -0.57  0.66 -0.31 -0.31    -0.39
# indus    0.41 -0.53   1.00  0.06  0.76 -0.39  0.64 -0.71  0.60  0.72     0.38
# chas    -0.06 -0.04   0.06  1.00  0.09  0.09  0.09 -0.10 -0.01 -0.04    -0.12
# nox      0.42 -0.52   0.76  0.09  1.00 -0.30  0.73 -0.77  0.61  0.67     0.19
# rm      -0.22  0.31  -0.39  0.09 -0.30  1.00 -0.24  0.21 -0.21 -0.29    -0.36
# age      0.35 -0.57   0.64  0.09  0.73 -0.24  1.00 -0.75  0.46  0.51     0.26
# dis     -0.38  0.66  -0.71 -0.10 -0.77  0.21 -0.75  1.00 -0.49 -0.53    -0.23
# rad      0.63 -0.31   0.60 -0.01  0.61 -0.21  0.46 -0.49  1.00  0.91     0.46
# tax      0.58 -0.31   0.72 -0.04  0.67 -0.29  0.51 -0.53  0.91  1.00     0.46
# ptratio  0.29 -0.39   0.38 -0.12  0.19 -0.36  0.26 -0.23  0.46  0.46     1.00
# ...

# %%
sns.heatmap(Boston.corr())
# Out:
# <Axes: >

# %% [markdown]
# (e) Do any of the suburbs of Boston appear to have particularly
# high crime rates? Tax rates? Pupil-teacher ratios? Comment on
# the range of each predictor.

# %%
Boston.describe().round(2)
# Out:
#          crim      zn   indus    chas     nox      rm     age     dis     rad  \
# count  506.00  506.00  506.00  506.00  506.00  506.00  506.00  506.00  506.00
# mean     3.61   11.36   11.14    0.07    0.55    6.28   68.57    3.80    9.55
# std      8.60   23.32    6.86    0.25    0.12    0.70   28.15    2.11    8.71
# min      0.01    0.00    0.46    0.00    0.38    3.56    2.90    1.13    1.00
# 25%      0.08    0.00    5.19    0.00    0.45    5.89   45.02    2.10    4.00
# 50%      0.26    0.00    9.69    0.00    0.54    6.21   77.50    3.21    5.00
# 75%      3.68   12.50   18.10    0.00    0.62    6.62   94.07    5.19   24.00
# max     88.98  100.00   27.74    1.00    0.87    8.78  100.00   12.13   24.00
#
#           tax  ptratio   lstat    medv
# count  506.00   506.00  506.00  506.00
# mean   408.24    18.46   12.65   22.53
# std    168.54     2.16    7.14    9.20
# min    187.00    12.60    1.73    5.00
# 25%    279.00    17.40    6.95   17.02
# ...

# %% [markdown]
# Based on the data shown above, we can conclude that there are suburbs with high crime rates. the 75th percentile is at 3,68 yet there is a suburb at 88,98.
#
# This does not happen with the tax rates nor the Pupil to teacher ratio. the difference between the 75th percentile and the max value is not as big.
#
# This can also be shown through boxplots. In the first one we can see there are several outliers.

# %%
fig, ax = plt.subplots(1, 3, figsize = (10,10))
sns.boxplot(Boston['crim'], ax = ax[0])
sns.boxplot(Boston['tax'], ax = ax[1])
sns.boxplot(Boston['ptratio'], ax = ax[2])
# Out:
# <Axes: ylabel='ptratio'>

# %% [markdown]
# (f) How many of the suburbs in this data set bound the Charles
# river?

# %%
Boston[Boston['chas'] == 1].count()
# Out:
# crim       35
# zn         35
# indus      35
# chas       35
# nox        35
# rm         35
# age        35
# dis        35
# rad        35
# tax        35
# ptratio    35
# lstat      35
# medv       35
# dtype: int64

# %% [markdown]
# There are 35 suburbs that bound the Charles river

# %% [markdown]
# (g) What is the median pupil-teacher ratio among the towns in this
# data set?

# %%
Boston['ptratio'].mean().round(2)
# Out:
# 18.46

# %% [markdown]
# (h) Which suburb of Boston has lowest median value of owner-
# occupied homes? What are the values of the other predictors
# for that suburb, and how do those values compare to the overall
# ranges for those predictors? Comment on your findings.

# %%
Boston.nsmallest(1, columns = 'medv')
# Out:
#         crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 398  38.3518  0.0   18.1     0  0.693  5.453  100.0  1.4896   24  666
#
#      ptratio  lstat  medv
# 398     20.2  30.59   5.0

# %% [markdown]
# (i) In this data set, how many of the suburbs average more than
# seven rooms per dwelling? More than eight rooms per dwelling?
# Comment on the suburbs that average more than eight rooms
# per dwelling.

# %%
Boston[Boston['rm'] > 7].count()
# Out:
# crim       64
# zn         64
# indus      64
# chas       64
# nox        64
# rm         64
# age        64
# dis        64
# rad        64
# tax        64
# ptratio    64
# lstat      64
# medv       64
# dtype: int64

# %%
Boston[Boston['rm'] > 8].count()
# Out:
# crim       13
# zn         13
# indus      13
# chas       13
# nox        13
# rm         13
# age        13
# dis        13
# rad        13
# tax        13
# ptratio    13
# lstat      13
# medv       13
# dtype: int64

# %%
Boston[Boston['rm'] > 8].describe().round(2)
# Out:
#         crim     zn  indus   chas    nox     rm    age    dis    rad     tax  \
# count  13.00  13.00  13.00  13.00  13.00  13.00  13.00  13.00  13.00   13.00
# mean    0.72  13.62   7.08   0.15   0.54   8.35  71.54   3.43   7.46  325.08
# std     0.90  26.30   5.39   0.38   0.09   0.25  24.61   1.88   5.33  110.97
# min     0.02   0.00   2.68   0.00   0.42   8.03   8.40   1.80   2.00  224.00
# 25%     0.33   0.00   3.97   0.00   0.50   8.25  70.40   2.29   5.00  264.00
# 50%     0.52   0.00   6.20   0.00   0.51   8.30  78.30   2.89   7.00  307.00
# 75%     0.58  20.00   6.20   0.00   0.60   8.40  86.50   3.65   8.00  307.00
# max     3.47  95.00  19.58   1.00   0.72   8.78  93.90   8.91  24.00  666.00
#
#        ptratio  lstat   medv
# count    13.00  13.00  13.00
# mean     16.36   4.31  44.20
# std       2.41   1.37   8.09
# min      13.00   2.47  21.90
# 25%      14.70   3.32  41.70
# 50%      17.40   4.14  48.30
# 75%      17.40   5.12  50.00
# max      20.20   7.44  50.00
